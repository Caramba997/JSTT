# %%
import json
import matplotlib.pyplot as plt
import scipy.stats as stats
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('../rank_stars.csv', names=['rank', 'stars'], delimiter=',')

# %%
data.plot.scatter(x="rank", y="stars", s=3, figsize=(10,8))
plt.show()

# %%
data_top = pd.read_csv('../rank_stars_top.csv', names=['rank', 'stars'], delimiter=',')

# %%
data_top.plot.scatter(x="rank", y="stars", s=3, figsize=(10,2))
plt.show()
